# %% [markdown]
# <a href="https://colab.research.google.com/github/waterbeans77-cpu/make_CLI/blob/main/CLI_%EA%B2%8C%EC%8B%9C%ED%8C%90_%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("===CLI 게시판 실행===")

while True:
  cmd = input("명령어) : ")

  if cmd == "exit":
    break

  elif cmd == "article write":
    input("제목 : ")
    input("내용 : ")
    print("{}번 글이 생성 되었습니다.".format(x))

print("== CLI 게시판 종료 ==")
# Out:
# ===CLI 게시판 실행===
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1733/534991148.py in <cell line: 0>()
#       2
#       3 while True:
# ----> 4   cmd = input("명령어) : ")
#       5
#       6   if cmd == "exit":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
print("== CLI 게시판 실행 ==")


# 묶고 저장까지 했어야햇음


word_1 = []
word_2 = []
word_3 = []


i = 1

while True:
    cmd = input("명령어 ) ").strip()

    if cmd == "exit":
      break

    elif cmd == "article write":
      aa = input("제목 : ")
      bb = input("내용 : ")
      print("{}번 글이 생성 되었습니다.".format(i))
      i += 1

      word_1.append(i)
      word_2.append(aa)
      word_3.append(bb)


    elif cmd == "article list":
      print("==================================")

      print("번호    /    제목     /   내용")

      i = 1

      while i <= i :


        for index, value in enumerate(word_1, start = 1):
           for index, value in enumerate(word_2, start = 1):
            for index, value in enumerate(word_3, start = 1):
               print("{}     /     {}      /   {}.".format(id, word_2, word_3))

        i += 1
        id= i





      print("==================================")




    else:
      print("지원하지 않는 기능입니다")





print("== CLI 게시판 종료 ==")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 128367     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128368     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128368     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128368     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128368     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128368     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128368     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128368     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128368     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128369     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128369     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128369     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128369     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128369     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128369     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128369     /     ['dd', 'gg']      /   ['dd', 'gg'].
# 128369     /     ['dd', 'gg']      /   ['dd', 'gg'].
# ...

# %%
a = [100, 200, 300, 400]
for index, value in enumerate(a, start = 1):
  print(index, value)
# Out:
# 1 100
# 2 200
# 3 300
# 4 400

# %%
print("== CLI 게시판 실행 ==")

last_article_id = 0
articles = [] # 게시글 저장소
delete_id = []



while True:
    cmd = input("명령어 ) ").strip()

    if cmd == "exit":
      break

    elif cmd == "article write":
      last_article_id += 1
      id = last_article_id
      title = input("제목 : ")
      body = input("내용 : ")
      article = {"id" : id, "title" : title, "body" : body}
      # print(article)
      articles.append(article)
      print("{}번 글이 생성되었습니다".format(last_article_id))

    elif cmd == "article list":
      if not articles:
        print("게시글이 없습니다")
      else:
        print("=========================================")
        print("   번호      /     제목       /     내용   ")
        for a in reversed(articles):
          print("   {}      /     {}       /     {}   ".format(a["id"], a["title"], a["body"]))
        print("=========================================")



    elif cmd == "article delete 1":
      print("1번 글이 삭제 되었습니다.")



    elif cmd == "article delete {}".format(int(id_id)):    # split, startswith
      for article in articles:
        if f_article = articles.split("/"):
          a.startswith(a["id"]):
        if article['id'] == int(id):
          articles.remove(article[int(id)])
          print("{}번 글이 삭제 되었습니다.".format(int(id)))



        #= articles.split("/"):
        #if a.startswith(a["id"]):
         #  articles.remove(articles.a["id"])

      print("3번 글은 존재하지 않습니다.")

    else:
      print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) article write
# 제목 : 고구마
# 내용 : 좋아
# 1번 글이 생성되었습니다
# 명령어 ) article write
# 제목 : 감자
# 내용 : 싫어
# 2번 글이 생성되었습니다
# 명령어 ) article write
# 제목 : 돼지감자
# 내용 : 쏘소
# 3번 글이 생성되었습니다
# 명령어 ) article list
# ...
#    번호      /     제목       /     내용
#    3      /     돼지감자       /     쏘소
#    2      /     감자       /     싫어
#    1      /     고구마       /     좋아
# ...
# 명령어 ) article delete 3
# 지원하지 않는 기능입니다
# 명령어 ) article delete id
# 지원하지 않는 기능입니다
# 명령어 ) article delete 3
# 지원하지 않는 기능입니다
# 명령어 ) article delete id
# 지원하지 않는 기능입니다
# 명령어 ) article delete 3
# 지원하지 않는 기능입니다
# 명령어 ) article delete 3
# 지원하지 않는 기능입니다
# 명령어 ) article delete 3
# 지원하지 않는 기능입니다
# 명령어 ) article delete 3
# 지원하지 않는 기능입니다
# 명령어 ) article delete 3
# 지원하지 않는 기능입니다
# 명령어 ) article delete 3
# 지원하지 않는 기능입니다
# 명령어 ) article delete 3
# 지원하지 않는 기능입니다
# 명령어 ) article delete 3
# 지원하지 않는 기능입니다
# 명령어 ) article delete 3
# 지원하지 않는 기능입니다
# 명령어 ) article list
# ...
#    번호      /     제목       /     내용
#    3      /     돼지감자       /     쏘소
# ...

# %%
print("== CLI 게시판 실행 ==")

last_article_id = 0
articles = [] # 게시글 저장소

while True:
    cmd = input("명령어 ) ").strip()

    if cmd == "exit":
      break

    elif cmd == "article write":
      last_article_id += 1
      id = last_article_id
      title = input("제목 : ")
      body = input("내용 : ")
      article = {"id" : id, "title" : title, "body" : body}
      # print(article)
      articles.append(article)
      print("{}번 글이 생성되었습니다".format(last_article_id))

    elif cmd == "article list":
      if not articles:
        print("게시글이 없습니다")
      else:
        print("=========================================")
        print("   번호      /     제목       /     내용   ")
        for a in reversed(articles):
          print("   {}      /     {}       /     {}   ".format(a["id"], a["title"], a["body"]))
        print("=========================================")
    elif cmd.startswith("article delete"):
      cmdBits = cmd.split(" ")
      print(cmdBits[2])
    else:
      print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")
